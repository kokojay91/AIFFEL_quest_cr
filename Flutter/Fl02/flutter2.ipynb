# %% [markdown]
# <a href="https://colab.research.google.com/github/kokojay91/AIFFEL_quest_cr/blob/main/Flutter/Fl02/flutter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import 'package:flutter/material.dart';

void main() {
  runApp(MyApp());
}

class MyApp extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    return MaterialApp(
        debugShowCheckedModeBanner: false,
        home: Scaffold(
            appBar: AppBar(
              backgroundColor: Colors.blue,
              // AppBar의 배경색을 파란색으로 설정(테마에 따라 달라지기 때문에 명시적으로 지정해야 함)
              centerTitle: true,
              // 제목을 중앙에 배치
              title: TopScreen(),
            ),
            body: BodyScreen()
        )
    );
  }
}

class TopScreen extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    return Row(
        children: [
          Image.asset(
            'images/top.png',
            width: 50,
          ),
          SizedBox(width: 10),
          Container(
            width: 250,
            alignment: Alignment.center,
            child: Text(
                textAlign: TextAlign.center,
                '플러터 앱 만들기'
            ),
          )
        ]
    );
  }
}

class BodyScreen extends StatelessWidget {
  @override
  Widget build(BuildContext context) {
    final List<Color> colors = [
      Colors.red,
      Colors.orange,
      Colors.yellow,
      Colors.green,
      Colors.blue,
    ];

    final List<double> sizes = [300, 240, 180, 120, 60];

    return Center(
      child: Column(
        mainAxisAlignment: MainAxisAlignment.center, // 세로축에서 중앙 정렬
        children: [
          ElevatedButton(
              onPressed: (){
                print('버튼이 눌렸습니다.');
              },
              style: ElevatedButton.styleFrom(
                backgroundColor: Colors.purple, // 버튼 배경색 보라색으로 설정
                foregroundColor: Colors.white, // 버튼 글씨색 흰색
              ),
              child: Text('Text')
          ),
          SizedBox(height: 30),
          Stack(
            children: List.generate(
              colors.length,
                  (index) => Container(
                width: sizes[index],
                height: sizes[index],
                color: colors[index],
              ),
            ),
          ),
        ],
      ),
    );
  }
}

# %%
//기존코드1 를 간결하게 변경
Stack(
    children: [
      Container(
        width: 300,
        height: 300,
        color: Colors. red,
      ),
      Container(
        width: 240,
        height: 240,
        color: Colors. orange,
      ),
      Container(
        width: 180,
        height: 180,
        color: Colors. yellow,
      ),
      Container(
        width: 120,
        height: 120,
        color: Colors. green,
      ),
      Container(
        width: 60,
        height: 60,
        color: Colors. blue,
      ),


     // 기존코드2 에 alignment: Alignment.center 추가후 텍스트를 가운데 표시
      Container(
            width: 250,
            child: Text(
                textAlign: TextAlign.center,
                '플러터 앱 만들기'
            ),

      // 기존코드3 에 버튼 글씨색이 잘보이도록 백그라운드색과 글씨색 지정
       return Center(
        child: Column(
          mainAxisAlignment: MainAxisAlignment.center, // 세로축에서 중앙 정렬
          children: [
            ElevatedButton(
                onPressed: (){
                  print('버튼이 눌렸습니다.');
                },
                style: ElevatedButton.styleFrom(
                  backgroundColor: Colors.purple, // 버튼 배경색 보라색으로 설정
                  foregroundColor: Colors.white, // 버튼 글씨색 흰색

# %% [markdown]
# ![완성.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 이지선 회고
# ---
# 권중님께서 워낙 진행을 잘하시다보니 업혀가는 느낌이었습니다. 도움을 많이 도움을 드리지 못한것 같아 코드 진행하면서 수정된 부분이나 오류가 있었던 부분에 대해서 정리를 하는등 조그마한 도움이라도 되고 싶었습니다!
# 중간중간 코드에대해 궁금한 점도 물어보면 알려주시고 유익한 시간이었습니다
